# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import genfromtxt

# %% [markdown]
# ### Eigenvalues

# %% [markdown]
# #### 1. Logistic Noise

# %%
logistic_eigen_S_star_normal = genfromtxt('CSVs/logistic_logistic_eigen_S_star_normal.csv', delimiter=',')

# %%
logistic_logistic_eigen = genfromtxt('CSVs/logistic_logistic_eigen.csv', delimiter=',')

# %%
logistic_laplace_eigen = genfromtxt('CSVs/logistic_laplace_eigen.csv', delimiter=',')

# %%
logistic_HS_eigen = genfromtxt('CSVs/logistic_hs_eigen.csv', delimiter=',')

# %%
plt.plot(logistic_eigen_S_star_normal, label = 'eigenvalues of M_star/tau_star', color = 'blue')
plt.plot(logistic_logistic_eigen, label = 'Logistic Noise Logistic Model', color= 'red')
plt.plot(logistic_laplace_eigen, label = 'Logistic Noise Laplace Model', color= 'green')
plt.plot(logistic_HS_eigen, label = 'Logistic Noise HS Model', color= 'brown')

plt.legend()
plt.xlabel('#eigenvalue', fontsize=10)
plt.ylabel('eigenvalue', fontsize=10)
plt.title('eigenvalues of  M_hat/tau_hat and M_star/tau_star \n(Logistic Noise)', fontsize= 12)
plt.savefig("Images/eigen_logistic_all", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 2. Gaussian Noise

# %%
gaussian_eigen_S_star_normal = genfromtxt('CSVs/gaussian_logistic_eigen_S_star_normal.csv', delimiter=',')

# %%
gaussian_logistic_eigen = genfromtxt('CSVs/gaussian_logistic_eigen.csv', delimiter=',')

# %%
gaussian_laplace_eigen = genfromtxt('CSVs/gaussian_laplace_eigen.csv', delimiter=',')

# %%
gaussian_HS_eigen = genfromtxt('CSVs/gaussian_hs_eigen.csv', delimiter=',')

# %%
plt.plot(gaussian_eigen_S_star_normal, label = 'eigenvalues of M_star/tau_star', color = 'blue')
plt.plot(gaussian_logistic_eigen, label = 'Gaussian Noise Logistic Model', color= 'red')
plt.plot(gaussian_laplace_eigen, label = 'Gaussian Noise Laplace Model', color= 'green')
plt.plot(gaussian_HS_eigen, label = 'Gaussian Noise HS Model', color= 'brown')

plt.legend()
plt.xlabel('#eigenvalue', fontsize=10)
plt.ylabel('eigenvalue', fontsize=10)
plt.title('eigenvalues of  M_hat/tau_hat and M_star/tau_star \n(Gaussian Noise)', fontsize= 12)
plt.savefig("Images/eigen_Gaussian_all", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 3. Hs noise

# %%
HS_eigen_S_star_normal = genfromtxt('CSVs/hs_hs_eigen_S_star_normal.csv', delimiter=',')

# %%
HS_logistic_eigen = genfromtxt('CSVs/hs_logistic_eigen.csv', delimiter=',')

# %%
HS_laplace_eigen = genfromtxt('CSVs/hs_laplace_eigen.csv', delimiter=',')

# %%
HS_HS_eigen = genfromtxt('CSVs/hs_hs_eigen.csv', delimiter=',')

# %%
plt.plot(HS_eigen_S_star_normal, label = 'eigenvalues of M_star/tau_star', color = 'blue')
plt.plot(HS_logistic_eigen, label = 'HS Noise Logistic Model', color= 'red')
plt.plot(HS_laplace_eigen, label = 'HS Noise Laplace Model', color= 'green')
plt.plot(HS_HS_eigen, label = 'HS Noise HS Model', color= 'brown')

plt.legend()
plt.xlabel('#eigenvalue', fontsize=10)
plt.ylabel('eigenvalue', fontsize=10)
plt.title('eigenvalues of  M_hat/tau_hat and M_star/tau_star \n(HS Noise)', fontsize= 12)
plt.savefig("Images/eigen_HS_all", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Laplace Noise

# %%
Laplace_eigen_S_star_normal = genfromtxt('CSVs/laplace_laplace_eigen_S_star_normal.csv', delimiter=',')

# %%
Laplace_logistic_eigen = genfromtxt('CSVs/laplace_logistic_eigen.csv', delimiter=',')

# %%
Laplace_laplace_eigen = genfromtxt('CSVs/laplace_laplace_eigen.csv', delimiter=',')

# %%
Laplace_HS_eigen = genfromtxt('CSVs/laplace_hs_eigen.csv', delimiter=',')

# %%
plt.plot(Laplace_eigen_S_star_normal, label = 'eigenvalues of M_star/tau_star', color = 'blue')
plt.plot(Laplace_logistic_eigen, label = 'Laplace Noise Logistic Model', color= 'red')
plt.plot(Laplace_laplace_eigen, label = 'Laplace Noise Laplace Model', color= 'green')
plt.plot(Laplace_HS_eigen, label = 'Laplace Noise HS Model', color= 'brown')

plt.legend()
plt.xlabel('#eigenvalue', fontsize=10)
plt.ylabel('eigenvalue', fontsize=10)
plt.title('eigenvalues of  M_hat/tau_hat and M_star/tau_star \n(Laplace Noise)', fontsize= 12)
plt.savefig("Images/eigen_laplace_all", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 4. Noisy Labeling

# %%
Laplace_eigen_S_star_normal = genfromtxt('CSVs/noisy_labeling_logistic_eigen_S_star_normal.csv', delimiter=',')

# %%
Laplace_logistic_eigen = genfromtxt('CSVs/noisy_labeling_logistic_eigen.csv', delimiter=',')

# %%
Laplace_laplace_eigen = genfromtxt('CSVs/noisy_labeling_logistic_eigen.csv', delimiter=',')

# %%
Laplace_HS_eigen = genfromtxt('CSVs/noisy_labeling_logistic_eigen.csv', delimiter=',')

# %%
plt.plot(Laplace_eigen_S_star_normal, label = 'eigenvalues of M_star/tau_star', color = 'blue')
plt.plot(Laplace_logistic_eigen, label = 'Noisy Labeling Logistic Model', color= 'red')
plt.plot(Laplace_laplace_eigen, label = 'Noisy Labeling Laplace Model', color= 'green')
plt.plot(Laplace_HS_eigen, label = 'Noisy Labeling HS Model', color= 'brown')

plt.legend()
plt.xlabel('#eigenvalue', fontsize=10)
plt.ylabel('eigenvalue', fontsize=10)
plt.title('eigenvalues of  M_hat/tau_hat and M_star/tau_star \n(Noisy Labeling)', fontsize= 12)
plt.savefig("Images/eigen_noisy_labeling_all", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Test accuracy, no noise

# %% [markdown]
# ### 1. Logistic model vs Logistic Noise

# %%
csv_path = 'CSVs/logistic_logistic_'

# %%
logistic_logistic_noise_list_history = genfromtxt(csv_path + 'noise_list_history.csv', delimiter=',')

# %%
logistic_logistic_test_accuracy_no_noise = genfromtxt(csv_path + "test_accuracy_no_noise.csv", delimiter=',')

# %%
logistic_logistic_test_accuracy_noisy = genfromtxt(csv_path + "test_accuracy_noisy.csv", delimiter=',')

# %%
logistic_logistic_train_accuracy_no_noise = genfromtxt(csv_path + "train_accuracy_no_noisy.csv", delimiter=',')

# %%
logistic_logistic_train_accuracy_noisy = genfromtxt(csv_path + "train_accuracy_noisy.csv", delimiter=',')

# %% [markdown]
# ### 2. Logistic Model vs Gaussian Noise

# %%
csv_path = 'CSVs/gaussian_logistic_'

# %%
gaussian_logistic_noise_list_history = genfromtxt(csv_path + 'noise_list_history.csv', delimiter=',')

# %%
gaussian_logistic_test_accuracy_no_noise = genfromtxt(csv_path + "test_accuracy_no_noise.csv", delimiter=',')

# %%
gaussian_logistic_test_accuracy_noisy = genfromtxt(csv_path + "test_accuracy_noisy.csv", delimiter=',')

# %%
gaussian_logistic_train_accuracy_no_noise = genfromtxt(csv_path + "train_accuracy_no_noisy.csv", delimiter=',')

# %%
gaussian_logistic_train_accuracy_noisy = genfromtxt(csv_path + "train_accuracy_noisy.csv", delimiter=',')

# %% [markdown]
# ### 3. Logistic Model vs Laplace Noise

# %%
csv_path = 'CSVs/laplace_logistic_'

# %%
laplace_logistic_noise_list_history = genfromtxt(csv_path + 'noise_list_history.csv', delimiter=',')

# %%
laplace_logistic_test_accuracy_no_noise = genfromtxt(csv_path + "test_accuracy_no_noise.csv", delimiter=',')

# %%
laplace_logistic_test_accuracy_noisy = genfromtxt(csv_path + "test_accuracy_noisy.csv", delimiter=',')

# %%
laplace_logistic_train_accuracy_no_noise = genfromtxt(csv_path + "train_accuracy_no_noisy.csv", delimiter=',')

# %%
laplace_logistic_train_accuracy_noisy = genfromtxt(csv_path + "train_accuracy_noisy.csv", delimiter=',')

# %% [markdown]
# #### 4. Logistic Model vs HS Noise

# %%
csv_path = 'CSVs/hs_logistic_'

# %%
hs_logistic_noise_list_history = genfromtxt(csv_path + 'noise_list_history.csv', delimiter=',')

# %%
hs_logistic_test_accuracy_no_noise = genfromtxt(csv_path + "test_accuracy_no_noise.csv", delimiter=',')

# %%
hs_logistic_test_accuracy_noisy = genfromtxt(csv_path + "test_accuracy_noisy.csv", delimiter=',')

# %%
hs_logistic_train_accuracy_no_noise = genfromtxt(csv_path + "train_accuracy_no_noisy.csv", delimiter=',')

# %%
hs_logistic_train_accuracy_noisy = genfromtxt(csv_path + "train_accuracy_noisy.csv", delimiter=',')

# %% [markdown]
# ### Logistic Model vs Noisy Labeling

# %%
csv_path = 'CSVs/noisy_labeling_logistic_'

# %%
noisy_labeling_logistic_noise_list_history = genfromtxt(csv_path + 'noise_list_history.csv', delimiter=',')

# %%
noisy_labeling_logistic_test_accuracy_no_noise = genfromtxt(csv_path + "test_accuracy_no_noise.csv", delimiter=',')

# %%
noisy_labeling_logistic_test_accuracy_noisy = genfromtxt(csv_path + "test_accuracy_noisy.csv", delimiter=',')

# %%
noisy_labeling_logistic_train_accuracy_no_noise = genfromtxt(csv_path + "train_accuracy_no_noisy.csv", 
                                                             delimiter=',')

# %%
noisy_labeling_logistic_train_accuracy_noisy = genfromtxt(csv_path + "train_accuracy_noisy.csv", 
                                                             delimiter=',')

# %% [markdown]
# ### Logistic Model: Test accuracies without noise

# %%
plt.plot(logistic_logistic_noise_list_history, 
         logistic_logistic_test_accuracy_no_noise, 
         label = 'test accuracy no noise (Logistic noise)', 
         color = 'blue')

plt.plot(gaussian_logistic_noise_list_history, 
         gaussian_logistic_test_accuracy_no_noise, 
         label = 'test accuracy no noise (Gaussian noise)', 
         color = 'green')

plt.plot(laplace_logistic_noise_list_history, 
         laplace_logistic_test_accuracy_no_noise, 
         label = 'test accuracy no noise (Laplace noise)', 
         color = 'brown')

plt.plot(hs_logistic_noise_list_history, 
         hs_logistic_test_accuracy_no_noise, 
         label = 'test accuracy no noise (HS noise)', 
         color = 'red')

plt.plot(noisy_labeling_logistic_noise_list_history, 
         noisy_labeling_logistic_test_accuracy_no_noise, 
         label = 'test accuracy no noise (Noisy labeling)', 
         color = 'magenta')

plt.legend()
plt.xlabel('noise', fontsize = 10)
plt.ylabel('accuracy', fontsize = 10)
plt.title('Logistic Models test accuracy (no noise) vs noise', fontsize = 12)
plt.savefig('Images/logistic_model_test_accuracy_(no_noise)_vs_noise')
plt.show()

# %% [markdown]
# ### Logistic Model: Test accuracies with noise

# %%
plt.plot(logistic_logistic_noise_list_history, 
         logistic_logistic_test_accuracy_noisy, 
         label = 'test accuracy noisy (Logistic noise)', 
         color = 'blue')

plt.plot(gaussian_logistic_noise_list_history, 
         gaussian_logistic_test_accuracy_noisy, 
         label = 'test accuracy noisy (Gaussian noise)', 
         color = 'green')

plt.plot(laplace_logistic_noise_list_history, 
         laplace_logistic_test_accuracy_noisy, 
         label = 'test accuracy noisy (Laplace noise)', 
         color = 'brown')

plt.plot(hs_logistic_noise_list_history, 
         hs_logistic_test_accuracy_noisy, 
         label = 'test accuracy noisy (HS noise)', 
         color = 'red')

plt.plot(noisy_labeling_logistic_noise_list_history, 
         noisy_labeling_logistic_test_accuracy_noisy, 
         label = 'test accuracy noisy (Noisy labeling)', 
         color = 'magenta')

plt.legend()
plt.xlabel('noise', fontsize = 10)
plt.ylabel('accuracy', fontsize = 10)
plt.title('Logistic Models test accuracy (noisy) vs noise', fontsize = 12)
plt.savefig('Images/1_logistic_model_test_accuracy_(noisy)_vs_noise')
plt.show()

# %% [markdown]
# ### Logistic Model: Train accuracies with noise

# %%
plt.plot(logistic_logistic_noise_list_history, 
         logistic_logistic_train_accuracy_no_noise, 
         label = 'train accuracy no noise (Logistic noise)', 
         color = 'blue')

plt.plot(gaussian_logistic_noise_list_history, 
         gaussian_logistic_train_accuracy_no_noise, 
         label = 'train accuracy no noise (Gaussian noise)', 
         color = 'green')

plt.plot(laplace_logistic_noise_list_history, 
         laplace_logistic_train_accuracy_no_noise, 
         label = 'train accuracy no noise (Laplace noise)', 
         color = 'brown')

plt.plot(hs_logistic_noise_list_history, 
         hs_logistic_train_accuracy_no_noise, 
         label = 'train accuracy no noise (HS noise)', 
         color = 'red')

plt.plot(noisy_labeling_logistic_noise_list_history, 
         noisy_labeling_logistic_train_accuracy_no_noise, 
         label = 'train accuracy no noise (Noisy labeling)', 
         color = 'magenta')

plt.legend()
plt.xlabel('noise', fontsize = 10)
plt.ylabel('accuracy', fontsize = 10)
plt.title('Logistic Models train accuracy (no noise) vs noise', fontsize = 12)
plt.savefig('Images/1_logistic_model_train_accuracy_(no_noise)_vs_noise')
plt.show()

# %%
plt.plot(logistic_logistic_noise_list_history, 
         logistic_logistic_train_accuracy_noisy, 
         label = 'train accuracy noisy (Logistic noise)', 
         color = 'blue')

plt.plot(gaussian_logistic_noise_list_history, 
         gaussian_logistic_train_accuracy_noisy, 
         label = 'train accuracy noisy (Gaussian noise)', 
         color = 'green')

plt.plot(laplace_logistic_noise_list_history, 
         laplace_logistic_train_accuracy_noisy, 
         label = 'train accuracy noisy (Laplace noise)', 
         color = 'brown')

plt.plot(hs_logistic_noise_list_history, 
         hs_logistic_train_accuracy_noisy, 
         label = 'train accuracy noisy (HS noise)', 
         color = 'red')

plt.plot(noisy_labeling_logistic_noise_list_history, 
         noisy_labeling_logistic_train_accuracy_noisy, 
         label = 'train accuracy noisy (Noisy labeling)', 
         color = 'magenta')

plt.legend()
plt.xlabel('noise', fontsize = 10)
plt.ylabel('accuracy', fontsize = 10)
plt.title('Logistic Models train accuracy (noisy) vs noise', fontsize = 12)
plt.savefig('Images/logistic_model_train_accuracy_(noisy)_vs_noise', bbox_inches='tight')
plt.show()

# %%
plt.plot(logistic_logistic_noise_list_history, 
         logistic_logistic_train_accuracy_no_noise, 
         label = 'train accuracy no noise (Logistic noise)', 
         color = 'brown')

plt.plot(logistic_logistic_noise_list_history, 
         logistic_logistic_test_accuracy_no_noise, 
         label = 'test accuracy no noise (Logistic noise)', 
         color = 'blue')

plt.plot(logistic_logistic_noise_list_history, 
         logistic_logistic_train_accuracy_noisy, 
         label = 'train accuracy noisy (Logistic noise)', 
         color = 'green')

plt.plot(logistic_logistic_noise_list_history, 
         logistic_logistic_test_accuracy_noisy, 
         label = 'test accuracy noisy (Logistic noise)', 
         color = 'magenta')




plt.legend()
plt.xlabel('noise', fontsize = 10)
plt.ylabel('accuracy', fontsize = 10)
plt.title('Logistic Models, accuracy vs noise', fontsize = 12)
plt.savefig('Images/logistic_model_accuracy_vs_noise', bbox_inches='tight')
plt.show()

# %%
plt.plot(noise_list_history_logistic[:], 
         test_accuracy_no_noise_logistic, 
         label = 'test accuracy no noise (Logistic)', 
         color = 'magenta')

plt.plot(noise_list_history_Gaussian[:], 
         test_accuracy_no_noise_Gaussian, 
         label = 'test accuracy no noise (Gaussian)', 
         color = 'green')

plt.plot(noise_list_history_Noisy_labeling, 
         test_accuracy_no_noise_Noisy_labeling, 
         label = 'test accuracy no noise (Noisy labeling)', 
         color = 'blue')

plt.legend()
plt.xlabel('noise', fontsize = 10)
plt.ylabel('accuracy', fontsize = 10)
plt.title('test_accuracy (no noise) vs noise', fontsize = 12)
plt.savefig('Images/Test_accuracy_(no_noise)_vs_noise')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0y/hx4crw9178xfvr_01vxxcmkh0000gn/T/ipykernel_90747/4219723750.py in <module>
# ----> 1 plt.plot(noise_list_history_logistic[:],
#       2          test_accuracy_no_noise_logistic,
#       3          label = 'test accuracy no noise (Logistic)',
#       4          color = 'magenta')
#       5
#
# NameError: name 'noise_list_history_logistic' is not defined

# %% [markdown]
# ### Train accuracy, no noise

# %%
train_accuracy_no_noise_logistic = genfromtxt('CSVs/logistic/train_accuracy_no_noisy.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/0y/hx4crw9178xfvr_01vxxcmkh0000gn/T/ipykernel_90747/1942886106.py in <module>
# ----> 1 train_accuracy_no_noise_logistic = genfromtxt('CSVs/logistic/train_accuracy_no_noisy.csv', delimiter=',')
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    1789             fname = os_fspath(fname)
#    1790         if isinstance(fname, str):
# -> 1791             fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1792             fid_ctx = contextlib.closing(fid)
#    1793         else:
#
# ...

# %%
train_accuracy_no_noise_Gaussian = genfromtxt('CSVs/Gaussian/train_accuracy_no_noisy.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/0y/hx4crw9178xfvr_01vxxcmkh0000gn/T/ipykernel_90747/1316973335.py in <module>
# ----> 1 train_accuracy_no_noise_Gaussian = genfromtxt('CSVs/Gaussian/train_accuracy_no_noisy.csv', delimiter=',')
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    1789             fname = os_fspath(fname)
#    1790         if isinstance(fname, str):
# -> 1791             fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1792             fid_ctx = contextlib.closing(fid)
#    1793         else:
#
# ...

# %%
train_accuracy_no_noise_Noisy_labeling = genfromtxt('CSVs/Noisy_labeling/train_accuracy_no_noisy.csv', delimiter=',')

# %%
plt.plot(noise_list_history_logistic[:], 
         train_accuracy_no_noise_logistic, 
         label = 'Train accuracy no noise (Logistic)', 
         color = 'magenta')

plt.plot(noise_list_history_Gaussian[:], 
         train_accuracy_no_noise_Gaussian, 
         label = 'Train accuracy no noise (Gaussian)', 
         color = 'green')

plt.plot(noise_list_history_Noisy_labeling, 
         train_accuracy_no_noise_Noisy_labeling, 
         label = 'Train accuracy no noise (Noisy labeling)', 
         color = 'blue')

plt.legend()
plt.xlabel('noise', fontsize = 10)
plt.ylabel('accuracy', fontsize = 10)
plt.title('Train accuracy (no noise) vs noise', fontsize = 12)
plt.savefig('Images/Train_accuracy_(no_noise)_vs_noise')
plt.show()

# %% [markdown]
# ### Train accuracy, noisy

# %%
train_accuracy_noisy_logistic = genfromtxt('CSVs/logistic/train_accuracy_noisy.csv', delimiter=',')
train_accuracy_noisy_Gaussian = genfromtxt('CSVs/Gaussian/train_accuracy_noisy.csv', delimiter=',')
train_accuracy_noisy_Noisy_labeling = genfromtxt('CSVs/Noisy_labeling/train_accuracy_noisy.csv', delimiter=',')

# %%
plt.plot(noise_list_history_logistic[:], 
         train_accuracy_noisy_logistic, 
         label = 'Train accuracy noisy (Logistic)', 
         color = 'magenta')

plt.plot(noise_list_history_Gaussian[:], 
         train_accuracy_noisy_Gaussian, 
         label = 'Train accuracy noisy (Gaussian)', 
         color = 'green')

plt.plot(noise_list_history_Noisy_labeling, 
         train_accuracy_noisy_Noisy_labeling, 
         label = 'Train accuracy noisy (Noisy labeling)', 
         color = 'blue')

plt.legend()
plt.xlabel('noise', fontsize = 10)
plt.ylabel('accuracy', fontsize = 10)
plt.title('Train accuracy (noisey) vs noise', fontsize = 12)
plt.savefig('Images/Train_accuracy_(noisy)_vs_noise')
plt.show()

# %%
test_accuracy_noisy_logistic = genfromtxt('CSVs/logistic/test_accuracy_noisy.csv', delimiter=',')
test_accuracy_noisy_Gaussian = genfromtxt('CSVs/Gaussian/test_accuracy_noisy.csv', delimiter=',')
test_accuracy_noisy_Noisy_labeling = genfromtxt('CSVs/Noisy_labeling/test_accuracy_noisy.csv', delimiter=',')

# %%
plt.plot(noise_list_history_logistic[:], 
         test_accuracy_noisy_logistic, 
         label = 'Test accuracy noisy (Logistic)', 
         color = 'magenta')

plt.plot(noise_list_history_Gaussian[:], 
         test_accuracy_noisy_Gaussian, 
         label = 'Test accuracy noisy (Gaussian)', 
         color = 'green')

plt.plot(noise_list_history_Noisy_labeling, 
         test_accuracy_noisy_Noisy_labeling, 
         label = 'Test accuracy noisy (Noisy labeling)', 
         color = 'blue')

plt.legend()
plt.xlabel('noise', fontsize = 10)
plt.ylabel('accuracy', fontsize = 10)
plt.title('Test accuracy (noisey) vs noise', fontsize = 12)
plt.savefig('Images/Test_accuracy_(noisy)_vs_noise')
plt.show()

# %% [markdown]
# ### Loss history

# %%
index_loss_history = genfromtxt('CSVs/logistic_logistic_index_loss_history.csv', delimiter=',')

# %%
logistic_model_true_loss_history = genfromtxt('CSVs/logistic_logistic_true_loss_history.csv', delimiter=',')

# %%
logistic_logistic_loss_history = genfromtxt('CSVs/logistic_logistic_model.loss_history.csv', delimiter=',')

# %%
gaussian_logistic_loss_history = genfromtxt('CSVs/gaussian_logistic_model.loss_history.csv', delimiter=',')

# %%
laplace_logistic_loss_history = genfromtxt('CSVs/laplace_logistic_model.loss_history.csv', delimiter=',')

# %%
hs_logistic_loss_history = genfromtxt('CSVs/hs_logistic_model.loss_history.csv', delimiter=',')

# %%
Noisy_labeling_logistic_loss_history = genfromtxt('CSVs/Noisy_labeling_logistic_model.loss_history.csv', delimiter=',')

# %%
plt.plot(index_loss_history[:21], logistic_model_true_loss_history[:21], label = 'Logistic model loss on M^*, tau^*', 
         color = 'red')

plt.plot(index_loss_history[:21], logistic_logistic_loss_history[:21], label = 'Logistic model loss for Logistic noise', 
         color = 'blue')

plt.plot(index_loss_history[:21], gaussian_logistic_loss_history[:21], label = 'Logistic model loss for Gaussian noise', 
         color = 'green')

plt.plot(index_loss_history[:21], laplace_logistic_loss_history[:21], label = 'Logistic model loss for Laplace noise', 
         color = 'brown')

plt.plot(index_loss_history[:21], hs_logistic_loss_history[:21], label = 'Logistic model loss for H-S noise', 
         color = 'magenta')

plt.plot(index_loss_history[:21], Noisy_labeling_logistic_loss_history[:21], label = 'Logistic model loss Noisy labeling', 
         color = 'black')
plt.legend()
plt.xlabel('# iteration', fontsize=10)
plt.ylabel('loss', fontsize=10)
plt.title('Logistic model loss history vs iteration', fontsize=12)
plt.savefig("Images/Logistic_model_loss_history_all_noises_vs_iteration")
plt.show()

# %% [markdown]
# ### $L_1(f)$-norm history

# %%
logistic_L_1_f_norm_history = genfromtxt("CSVs/logistic/model_L_1_f_norm_history.csv", delimiter=',')

# %%
gaussian_L_1_f_norm_history = genfromtxt("CSVs/gaussian/model_L_1_f_norm_history.csv", delimiter=',')

# %%
noisy_labeling_L_1_f_norm_history = genfromtxt("CSVs/noisy_labeling/model_L_1_f_norm_history.csv", delimiter=',')

# %%
plt.plot(index_loss_history[:], logistic_L_1_f_norm_history[:], 
         label = 'Logistic_L_1_f_norm_history', color = 'blue')

plt.plot(index_loss_history[:], gaussian_L_1_f_norm_history[:], 
         label = 'Gaussian_L_1_f_norm_history', color = 'green')

plt.plot(index_loss_history[:], noisy_labeling_L_1_f_norm_history[:], 
         label = 'Noisy_labeling_L_1_f_norm_history', color = 'brown')
plt.legend()
plt.xlabel('# iteration', fontsize=10)
plt.ylabel('norm_history', fontsize=10)
plt.title('L_1_f_norm_history vs iteration', fontsize=12)
plt.savefig("Images/norm_history_vs_iteration")
plt.show()
